# %%
import numpy as np 
import pandas as pd 
import matplotlib as plt 
import matplotlib.pyplot as py
# %matplotlib inline

# %%
df = pd.read_csv("C:\\Users\\dell\\OneDrive\\Desktop\\python_libraries campus-x\\Diwali Sales Data.csv")
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders  \
# 0     Maharashtra   Western       Healthcare             Auto       1
# 1  Andhra Pradesh  Southern             Govt             Auto       3
# 2   Uttar Pradesh   Central       Automobile             Auto       3
# 3       Karnataka  Southern     Construction             Auto       2
# 4         Gujarat   Western  Food Processing             Auto       2
#
#     Amount  Status  unnamed1
# 0  23952.0     NaN       NaN
# 1  23934.0     NaN       NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11239 non-null  float64
#  13  Status            0 non-null      float64
#  14  unnamed1          0 non-null      float64
# dtypes: float64(3), int64(4), object(8)
# memory usage: 1.3+ MB

# %%
df.drop(["Status","unnamed1"],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Gender', 'Age Group', 'Age',
#        'Marital_Status', 'State', 'Zone', 'Occupation', 'Product_Category',
#        'Orders', 'Amount'],
#       dtype='object')

# %%
df.isnull()
# Out:
#        User_ID  Cust_name  Product_ID  Gender  Age Group    Age  \
# 0        False      False       False   False      False  False
# 1        False      False       False   False      False  False
# 2        False      False       False   False      False  False
# 3        False      False       False   False      False  False
# 4        False      False       False   False      False  False
# ...        ...        ...         ...     ...        ...    ...
# 11246    False      False       False   False      False  False
# 11247    False      False       False   False      False  False
# 11248    False      False       False   False      False  False
# 11249    False      False       False   False      False  False
# 11250    False      False       False   False      False  False
#
#        Marital_Status  State   Zone  Occupation  Product_Category  Orders  \
# 0               False  False  False       False             False   False
# ...

# %%
#finding null values in Amount column
d = df[df["Amount"].isna()]
d
# Out:
#      User_ID Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 7    1002092  Shivangi  P00273442      F       55+   61               0
# 14   1003858      Cano  P00293742      M     46-50   46               1
# 16   1005447       Amy  P00275642      F     46-50   48               1
# 109  1005265    Sakshi  P00296242      F     46-50   48               1
# 111  1005261   Apoorva  P00057942      F     36-45   41               1
# 184  1005538    Kartik  P00269542      F     46-50   49               1
# 293  1000326  Jonathan  P00120542      M     51-55   53               0
# 344  1002507   Lakshmi  P00045842      F     26-35   35               1
# 345  1004498   Srishti  P00030842      F     51-55   55               0
# 452  1004601    Gaurav  P00014442      F     36-45   40               1
# 464  1004528    Anurag  P00338442      F     26-35   33               1
# 493  1002994    Hemant   P0009942      F     36-45   38               0
#
# ...

# %%
x= df["Amount"].fillna(0)
x
# Out:
# 0        23952.0
# 1        23934.0
# 2        23924.0
# 3        23912.0
# 4        23877.0
#           ...
# 11246      370.0
# 11247      367.0
# 11248      213.0
# 11249      206.0
# 11250      188.0
# Name: Amount, Length: 11251, dtype: float64

# %%
df.fillna(0)
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903    Sanskriti  P00125942      F     26-35   28               0
# 1      1000732       Kartik  P00110942      F     26-35   35               1
# 2      1001990        Bindu  P00118542      F     26-35   35               1
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# ...        ...          ...        ...    ...       ...  ...             ...
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11248  1001209        Oshin  P00201342      F     36-45   40               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
# 11250  1002744      Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
df["Amount"] = df["Amount"].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11251 entries, 0 to 11250
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11251 non-null  int64
#  1   Cust_name         11251 non-null  object
#  2   Product_ID        11251 non-null  object
#  3   Gender            11251 non-null  object
#  4   Age Group         11251 non-null  object
#  5   Age               11251 non-null  int64
#  6   Marital_Status    11251 non-null  int64
#  7   State             11251 non-null  object
#  8   Zone              11251 non-null  object
#  9   Occupation        11251 non-null  object
#  10  Product_Category  11251 non-null  object
#  11  Orders            11251 non-null  int64
#  12  Amount            11251 non-null  float64
# dtypes: float64(1), int64(4), object(8)
# memory usage: 1.1+ MB

# %%
m=df[df["Gender"]=="M"]
m
# Out:
#        User_ID    Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 3      1001425       Sudevi  P00237842      M      0-17   16               0
# 4      1000588         Joni  P00057942      M     26-35   28               1
# 5      1000588         Joni  P00057942      M     26-35   28               1
# 8      1003224       Kushal  P00205642      M     26-35   35               0
# 10     1003829     Harshita  P00200842      M     26-35   34               0
# ...        ...          ...        ...    ...       ...  ...             ...
# 11243  1005446      Sheetal  P00297742      M     51-55   53               0
# 11244  1005446      Sheetal  P00297742      M     51-55   53               0
# 11246  1000695      Manning  P00296942      M     18-25   19               1
# 11247  1004089  Reichenbach  P00171342      M     26-35   33               0
# 11249  1004023       Noonan  P00059442      M     36-45   37               0
#
# ...

# %%
m.shape
# Out:
# (3409, 13)

# %%
f=df[df["Gender"]=="F"]
f
# Out:
#        User_ID   Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0      1002903   Sanskriti  P00125942      F     26-35   28               0
# 1      1000732      Kartik  P00110942      F     26-35   35               1
# 2      1001990       Bindu  P00118542      F     26-35   35               1
# 6      1001132        Balk  P00018042      F     18-25   25               1
# 7      1002092    Shivangi  P00273442      F       55+   61               0
# ...        ...         ...        ...    ...       ...  ...             ...
# 11241  1003032    Matthias  P00058042      F     26-35   33               0
# 11242  1004344  Hildebrand  P00185442      F     26-35   27               1
# 11245  1004140   Bertelson  P00057442      F     26-35   31               1
# 11248  1001209       Oshin  P00201342      F     36-45   40               0
# 11250  1002744     Brumley  P00281742      F     18-25   19               0
#
# ...

# %%
f.shape
# Out:
# (7842, 13)

# %%
u=df["Product_Category"].unique()
for a, b in enumerate(u):
    print(a, b)
# Out:
# 0 Auto
# 1 Hand & Power Tools
# 2 Stationery
# 3 Tupperware
# 4 Footwear & Shoes
# 5 Furniture
# 6 Food
# 7 Games & Toys
# 8 Sports Products
# 9 Books
# 10 Electronics & Gadgets
# 11 Decor
# 12 Clothing & Apparel
# 13 Beauty
# 14 Household items
# 15 Pet Care
# 16 Veterinary
# 17 Office

# %%
u = df["Product_Category"].unique()
for a, b in enumerate(u):
    print(a, b)
# Out:
# 0 Auto
# 1 Hand & Power Tools
# 2 Stationery
# 3 Tupperware
# 4 Footwear & Shoes
# 5 Furniture
# 6 Food
# 7 Games & Toys
# 8 Sports Products
# 9 Books
# 10 Electronics & Gadgets
# 11 Decor
# 12 Clothing & Apparel
# 13 Beauty
# 14 Household items
# 15 Pet Care
# 16 Veterinary
# 17 Office

# %%
s=df.groupby("State")
s.first()
# Out:
#                   User_ID     Cust_name Product_ID Gender Age Group  Age  \
# State
# Andhra Pradesh    1000732        Kartik  P00110942      F     26-35   35
# Bihar             1001912         Hazel  P00087442      F     26-35   27
# Delhi             1003829      Harshita  P00200842      M     26-35   34
# Gujarat           1000588          Joni  P00057942      M     26-35   28
# Haryana           1003745       Shivani  P00220042      M     26-35   29
# Himachal Pradesh  1000588          Joni  P00057942      M     26-35   28
# Jharkhand         1004957    Inderpreet  P00111842      M     26-35   27
# Karnataka         1001425        Sudevi  P00237842      M      0-17   16
# Kerala            1000687         Neola  P00156442      M     26-35   35
# Madhya Pradesh    1003858          Cano  P00293742      M     46-50   46
# Maharashtra       1002903     Sanskriti  P00125942      F     26-35   28
# Punjab            1006009        Aditya  P00148642      M     26-35   28
# ...

# %%
e=df.groupby(['State','Amount'])["Gender"].sum()
e
# Out:
# State           Amount
# Andhra Pradesh  0.0         F
#                 560.0       M
#                 739.0       M
#                 883.0      MM
#                 953.0       M
#                            ..
# Uttarakhand     20239.0     F
#                 20432.0     F
#                 20468.0     F
#                 20608.0     F
#                 20623.0     F
# Name: Gender, Length: 10476, dtype: object

# %%
#TO SEE WHICH COUNTRY HAS GENERATED MORE SALES
grouped = df.groupby(['State','Gender'])['Amount'].sum()
print(grouped)
# Out:
# State             Gender
# Andhra Pradesh    F          5511219.99
#                   M          2525927.00
# Bihar             F          2819281.00
#                   M          1203476.00
# Delhi             F          8264499.45
#                   M          3339320.00
# Gujarat           F          2832262.00
#                   M          1113820.00
# Haryana           F          3198296.00
#                   M          1021879.00
# Himachal Pradesh  F          3163299.00
#                   M          1800069.00
# Jharkhand         F          1954275.00
#                   M          1072181.00
# Karnataka         F          9933966.00
#                   M          3589574.00
# Kerala            F          2644087.99
#                   M          1250404.00
# Madhya Pradesh    F          5301046.00
#                   M          2800096.00
# Maharashtra       F         10560976.00
#                   M          3866567.00
# Punjab            F           950267.00
# ...

# %%
h=df.groupby('Occupation')["Age Group"]
h.first()
# Out:
# Occupation
# Agriculture        36-45
# Automobile         26-35
# Aviation           26-35
# Banking            26-35
# Chemical           26-35
# Construction        0-17
# Food Processing    26-35
# Govt               26-35
# Healthcare         26-35
# Hospitality        46-50
# IT Sector            55+
# Lawyer             18-25
# Media              26-35
# Retail             18-25
# Textile            46-50
# Name: Age Group, dtype: object

# %%
j=df.groupby('Product_Category')["Amount"].sum().sort_values(ascending=False)
j
# Out:
# Product_Category
# Food                     33933883.50
# Clothing & Apparel       16495019.00
# Electronics & Gadgets    15643846.00
# Footwear & Shoes         15575209.45
# Furniture                 5440051.99
# Games & Toys              4331694.00
# Sports Products           3635933.00
# Beauty                    1959484.00
# Auto                      1958609.99
# Stationery                1676051.50
# Household items           1569337.00
# Tupperware                1155642.00
# Books                     1061478.00
# Decor                      730360.00
# Pet Care                   482277.00
# Hand & Power Tools         405618.00
# Veterinary                 112702.00
# Office                      81936.00
# Name: Amount, dtype: float64

# %%
b=f.groupby('Zone')["Amount"].sum().sort_values(ascending=False)
b
# Out:
# Zone
# Central     28820668.45
# Southern    18793087.98
# Western     13393238.00
# Northern     8555306.00
# Eastern      4773556.00
# Name: Amount, dtype: float64

# %%
import seaborn as sns 
sns.catplot(x='Zone',y='Amount',kind='bar',hue='Gender',data=df)

# %%
sns.catplot(x="Amount",y='Product_Category',kind='bar',data=df)

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942      F     26-35   28               0
# 1  1000732     Kartik  P00110942      F     26-35   35               1
# 2  1001990      Bindu  P00118542      F     26-35   35               1
# 3  1001425     Sudevi  P00237842      M      0-17   16               0
# 4  1000588       Joni  P00057942      M     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
d=df["Occupation"].unique()
d.shape
# Out:
# (15,)

# %%
df.count()
# Out:
# User_ID             11251
# Cust_name           11251
# Product_ID          11251
# Gender              11251
# Age Group           11251
# Age                 11251
# Marital_Status      11251
# State               11251
# Zone                11251
# Occupation          11251
# Product_Category    11251
# Orders              11251
# Amount              11251
# dtype: int64

# %%
h=df.groupby(["Occupation","Gender"])
h.first()
# Out:
#                         User_ID    Cust_name Product_ID Age Group  Age  \
# Occupation      Gender
# Agriculture     F       1001389       Smriti  P00261542     26-35   33
#                 M       1005493      Stewart  P00036242     36-45   45
# Automobile      F       1001990        Bindu  P00118542     26-35   35
#                 M       1001680      Vasudev  P00324942     26-35   26
# Aviation        F       1001193         Mick  P00004842     26-35   29
#                 M       1000687        Neola  P00156442     26-35   35
# Banking         F       1000416  Hrisheekesh  P00181842     46-50   46
#                 M       1003829     Harshita  P00200842     26-35   34
# Chemical        F       1001496   Haushalter  P00067942     26-35   35
#                 M       1002511       Ananya  P00148642     26-35   34
# Construction    F       1004416        Airdo  P00213742     18-25   23
#                 M       1001425       Sudevi  P00237842      0-17   16
# ...

# %%
c=df["Gender"]=df['Gender'].replace({'M':1,'F':0})
c
# Out:
# 0        0
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 11246    1
# 11247    1
# 11248    0
# 11249    1
# 11250    0
# Name: Gender, Length: 11251, dtype: int64

# %%
h=df.groupby(["Occupation","Gender"])
h.first()
# Out:
#                         User_ID    Cust_name Product_ID Age Group  Age  \
# Occupation      Gender
# Agriculture     0       1001389       Smriti  P00261542     26-35   33
#                 1       1005493      Stewart  P00036242     36-45   45
# Automobile      0       1001990        Bindu  P00118542     26-35   35
#                 1       1001680      Vasudev  P00324942     26-35   26
# Aviation        0       1001193         Mick  P00004842     26-35   29
#                 1       1000687        Neola  P00156442     26-35   35
# Banking         0       1000416  Hrisheekesh  P00181842     46-50   46
#                 1       1003829     Harshita  P00200842     26-35   34
# Chemical        0       1001496   Haushalter  P00067942     26-35   35
#                 1       1002511       Ananya  P00148642     26-35   34
# Construction    0       1004416        Airdo  P00213742     18-25   23
#                 1       1001425       Sudevi  P00237842      0-17   16
# ...

# %%
v = df[['Occupation', 'Gender']]
v
# Out:
#             Occupation  Gender
# 0           Healthcare       0
# 1                 Govt       0
# 2           Automobile       0
# 3         Construction       1
# 4      Food Processing       1
# ...                ...     ...
# 11246         Chemical       1
# 11247       Healthcare       1
# 11248          Textile       0
# 11249      Agriculture       1
# 11250       Healthcare       0
#
# [11251 rows x 2 columns]

# %%
df.head()
# Out:
#    User_ID  Cust_name Product_ID  Gender Age Group  Age  Marital_Status  \
# 0  1002903  Sanskriti  P00125942       0     26-35   28               0
# 1  1000732     Kartik  P00110942       0     26-35   35               1
# 2  1001990      Bindu  P00118542       0     26-35   35               1
# 3  1001425     Sudevi  P00237842       1      0-17   16               0
# 4  1000588       Joni  P00057942       1     26-35   28               1
#
#             State      Zone       Occupation Product_Category  Orders   Amount
# 0     Maharashtra   Western       Healthcare             Auto       1  23952.0
# 1  Andhra Pradesh  Southern             Govt             Auto       3  23934.0
# 2   Uttar Pradesh   Central       Automobile             Auto       3  23924.0
# 3       Karnataka  Southern     Construction             Auto       2  23912.0
# 4         Gujarat   Western  Food Processing             Auto       2  23877.0

# %%
sns.catplot(x="Gender",y='Occupation',kind='bar',legend_out=False,data=df)
